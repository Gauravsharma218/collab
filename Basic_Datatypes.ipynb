# %% [markdown]
# **Basic Data Types in python**
# 1. Integer
# 2. Floating Point
# 3. Complex
# 4. Boolean
# 5. String

# %%
a = 8
print(a)
# Out:
# 8

# %%
type(a)
# Out:
# int

# %%
b = 2.3
print(b)
type(b)
# Out:
# 2.3
# float

# %%
c = 1 + 3j
print(c)
type(c)
# Out:
# (1+3j)
# complex

# %% [markdown]
# **Coversion of One data type to another**

# %%
x = 10
print(x)
type(x)
# Out:
# 10
# int

# %%
y = float(x)
print(y)
type(y)
# Out:
# 10.0
# float

# %%
x = 5.88
print(x)
type(x)
# Out:
# 5.88
# float

# %%
y = int(x)
print(y)
type(y)
# Out:
# 5
# int

# %% [markdown]
# **Boolean**
# 1. True
# 2. False

# %%
a = True
print(a)
type(a)
# Out:
# True
# bool

# %%
b = False
print(b)
type(b)
# Out:
# False
# bool

# %%
a = 7<3
print(a)
type(a)
# Out:
# False
# bool

# %% [markdown]
# **String**

# %%
print("Machine Learning")
# Out:
# Machine Learning

# %%
my_string = 'Machine Learning'
print(my_string)
type(my_string)
# Out:
# Machine Learning
# str

# %%
print("Hello "*5)
# Out:
# Hello Hello Hello Hello Hello

# %% [markdown]
# **Slicing**

# %%
my_string = "programming"
print(my_string[1:5])
# Out:
# rogr

# %%
print(my_string[0:10:3])
# Out:
# pgmn

# %% [markdown]
# **String Concatenation**

# %%
word_1 = 'Machine'
word_2 = 'Learning'
print(word_1+word_2)
# Out:
# MachineLearning
