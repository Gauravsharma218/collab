# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauravsharma218/collab/blob/main/Baics_of_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Baics of python**

# %%
print("hello world")
# Out:
# hello world

# %%
print("machine learning "+"projects")
# Out:
# machine learning projects

# %%
print(10)
# Out:
# 10

# %%
print(8+3)
# Out:
# 11

# %% [markdown]
# **data types**

# %%
type(8+3)
# Out:
# int

# %%
type(5.4)
# Out:
# float

# %%
type('8')
# Out:
# str

# %% [markdown]
# **constant and variables**

# %%
player = "ronaldo"
print(player)
# Out:
# ronaldo

# %%
player1,player2,player3 = "ronaldo","messi","mbappe"
print(player1)
print(player2)
print(player3)
# Out:
# ronaldo
# messi
# mbappe

# %%
x = y= z = 23

# %%
print(y)
# Out:
# 23

# %% [markdown]
# **input**

# %%
num_1 = int(input("enetr the first number : "));
# Out:
# enetr the first number : 0

# %%
num2 = int(input("enter the the second number : "));
# Out:
# enter the the second number : 0

# %%
sum = num_1 +num2
print(sum)
# Out:
# 0

# %%
num = 5
print(float(num))
# Out:
# 5.0
