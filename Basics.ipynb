# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauravsharma218/collab/blob/main/Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# #print

# %%
print("hello world this is a new start")
# Out:
# hello world this is a new start

# %%
print("commit another one")
# Out:
# commit another one

# %% [markdown]
# to conactene two strings

# %%
print("Machine learning "+"Projects")
# Out:
# Machine learning Projects

# %% [markdown]
# #data types

# %%
type(8)
# Out:
# int

# %%
type(20.5)
# Out:
# float

# %%
type("gaurav")
# Out:
# str

# %% [markdown]
# #constant and variables

# %%
superhero ="iron man"
print(superhero)
# Out:
# iron man

# %%
superhero,captainamerica,batman="gaurav","rahul","john"
print(superhero)
print(captainamerica)
print(batman)
# Out:
# gaurav
# rahul
# john

# %%
x=y=z=23
print(x)
print(y)
print(z)
# Out:
# 23
# 23
# 23

# %% [markdown]
# #Input

# %% [markdown]
# here we have to specify the type of the input

# %%
number1 = input("Enter the number 1 :")
number2 = input("Enter the number 2 :")

sum = number1+number2
print(sum)
# Out:
# Enter the number 1 :12
# Enter the number 2 :12
# 1212

# %%
number1 = int(input("Enter the number 1 :"))
number2 = int(input("Enter the number 2 :"))

sum = number1+number2
print(sum)
# Out:
# Enter the number 1 :12
# Enter the number 2 :12
# 24
